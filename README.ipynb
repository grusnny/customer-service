# %% [markdown]
# # Andrés Felipe Ramírez Hernández

# %% [markdown]
# # customer-service
#  API- Node js + Express

# %% [markdown]
# # Post
# ![Post.png](data:image/png;base64,...)
# ![MongoDB Post.png](data:image/png;base64,...)

# %% [markdown]
# # Get
# ![Get.png](data:image/png;base64,...)
#
# ![Get_Id.png](data:image/png;base64,...)

# %% [markdown]
# # Put
# ![Put.png](data:image/png;base64,...)

# %% [markdown]
# # Delete
# ![Delete.png](data:image/png;base64,...)
# ![MongoDb Delete.png](data:image/png;base64,...)
